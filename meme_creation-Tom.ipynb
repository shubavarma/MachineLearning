# %%
# Import important python libraries
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
from matplotlib import image

# %%
# import PIL Module and Image library from it
import PIL
from PIL import Image

# %%
tomPil = Image.open(r"C:\Users\Kishore\197\MachineLearning\files_fonts\best-tom-and-jerry-funny-memes-templates-onlyhandpicked-1.jpeg")
type(tomPil)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
plt.imshow(tomPil)

# %%
# Adding text to image we will import ImageDraw and ImageFont libraries
from PIL import ImageDraw, ImageFont

# %%
# to add this font we use ImageFont
# we need to mention the font size looking at the scale of the image
font = ImageFont.truetype(r"C:\Users\Kishore\197\MachineLearning\files_fonts\Fira_Sans\FiraSans-Regular.ttf",
                          35)

# %%
# To draw on the image we need to create ImageDraw object
tomDraw = ImageDraw.Draw(tomPil)

# %%
# Adding text to the image
# we need to pass y,x cordinates where we want the text to start
# followed by the text we want to add
# what font to use
# this will be saved on to the Pil object
# To add brown tom's tag
tomDraw.text((100,400),
                text = 'Pandas \n Numpy \n matplotlib',
                font = font,
                fill = (255,255,255))

# %%
plt.imshow(tomPil)

# %%
# To add blue tom's tag
tomDraw.text((300,375),
                text = 'Data\nScientist ',
                font = font,
                fill = (255,255,255))

# %%
plt.imshow(tomPil)

# %%
# To add dark brown tom's tag
tomDraw.text((430,300),
                text = 'sklearn ',
                font = font,
                fill = (255,255,255))

plt.imshow(tomPil)

# %%
# To add black tom's tag
tomDraw.text((550,330),
                text = 'PyTorch ',
                font = font,
                fill = (255,255,255))

plt.imshow(tomPil)

# %%
# If we want to save this image
tomPil.save(r'C:\Users\Kishore\197\MachineLearning\files_fonts\tom.jpg')
