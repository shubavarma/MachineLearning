# %%
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn

# %%
df = sns.load_dataset('titanic')
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df = df[['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
       'embarked']]
df.sample(3)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked
# 424         0       3    male  18.0      1      1  20.2125        S
# 873         0       3    male  47.0      0      0   9.0000        S
# 241         1       3  female   NaN      1      0  15.5000        Q

# %%
df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# embarked      2
# dtype: int64

# %%
from sklearn.model_selection import train_test_split 

X, y = df.drop(columns = 'survived'), df['survived']

xTrain, xTest, yTrain, yTest = train_test_split(X,y,
                                                test_size = 0.32,
                                                random_state = 23)

# %%
xTrain.shape, xTest.shape, len(yTrain), len(yTest)
# Out:
# ((605, 7), (286, 7), 605, 286)

# %%
contCols = ['age', 'fare']
nominalCols = ['sex', 'embarked']

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
# pipeline for handling cont data

# we know there are missing values in age
# we also know the distributions of these cols are not normal

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, PowerTransformer

contPipeline = Pipeline(steps = [
    ('impute',SimpleImputer(strategy = ('median'))),
    ('yeoJohnsonTransformation', PowerTransformer()),
    ('scaler', StandardScaler()) 
])

# %%
# Pipeline for handling categorical cols

# we knew there are missing values in embarked
# we will be using one hot encoding to transform these nominal categorical data

from sklearn.preprocessing import OneHotEncoder

catPipeline = Pipeline(steps = [
    ('impute',SimpleImputer(strategy = ('most_frequent'))),
    ('oneHotEncoding', OneHotEncoder( sparse_output=False, handle_unknown='ignore'))
])

# %%
# we shall use column transformer to run these two pipelines parallely

preprocessor = ColumnTransformer(transformers = [
    ('contDataPipeLine', contPipeline, contCols),
    ('catNominalDataPipeLine', catPipeline, nominalCols)
    
],
remainder = 'passthrough')

# %%
# we will create another pipeline which acts as an final pipeline with estimator

from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()

dtcPipeline = Pipeline(steps = [
    ('preprocessor', preprocessor),
    ('dtcModel', dtc)
])

# %%
dtcPipeline.fit(xTrain, yTrain)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('contDataPipeLine',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('yeoJohnsonTransformation',
#                                                                    PowerTransformer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['age', 'fare']),
#                                                  ('catNominalDataPipeLine',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('oneHotEncoding',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['sex', 'embarked'])])),
#                 ('dtcModel', DecisionTreeClassifier())])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
yTrainPred = dtcPipeline.predict(xTrain)
accuracy_score(yTrain, yTrainPred)
# Out:
# 0.9818181818181818

# %%
yTestPred = dtcPipeline.predict(xTest)
accuracy_score(yTest, yTestPred)
# Out:
# 0.7867132867132867

# %%
# the overfitting might be a resultant of letting the tree grow to its max depth.
'''
import matplotlib.pyplot as plt
plt.figure(figsize = (15,15))
sklearn.tree.plot_tree(dtc)
'''
# Out:
# '\nimport matplotlib.pyplot as plt\nplt.figure(figsize = (15,15))\nsklearn.tree.plot_tree(dtc)\n'

# %%
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler

# %%
# we can use our final pipeline to perform k-fold cross validation using randomized search

from sklearn.model_selection import RandomizedSearchCV 



hyperParametersGrid =  {'dtcModel__criterion':['gini', 'entropy', 'log_loss'],
                        'dtcModel__max_depth' : np.arange(2,11),
                        'preprocessor__contDataPipeLine__scaler': [StandardScaler(), RobustScaler(), MinMaxScaler()],
                        'preprocessor__catNominalDataPipeLine__oneHotEncoding__drop':[None, 'first']} # model's name in the pipeline followed by two(2) '_'(underscores) and hyperparmetername


rsDtc = RandomizedSearchCV(dtcPipeline,
                     hyperParametersGrid,
                     n_iter=20,
                     cv = 15,
                     scoring = 'f1'
                     )

# %%
rsDtc.fit(xTrain, yTrain)
# Out:
# RandomizedSearchCV(cv=15,
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('contDataPipeLine',
#                                                                                Pipeline(steps=[('impute',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('yeoJohnsonTransformation',
#                                                                                                 PowerTransformer()),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['age',
#                                                                                 'fare']),
#                                                                               ('catNominalDataPipeLine',
#                                                                                Pipeline(steps=[('impute',
#                                                                                                 S...
#                                              ('dtcModel',
#                                               DecisionTreeClassifier())]),
#                    n_iter=20,
#                    param_distributions={'dtcModel__criterion': ['gini',
#                                                                 'entropy',
#                                                                 'log_loss'],
#                                         'dtcModel__max_depth': array([ 2,  3,  4,  5,  6,  7,  8,  9, 10]),
#                                         'preprocessor__catNominalDataPipeLine__oneHotEncoding__drop': [None,
#                                                                                                        'first'],
#                                         'preprocessor__contDataPipeLine__scaler': [StandardScaler(),
#                                                                                    RobustScaler(),
#                                                                                    MinMaxScaler()]},
#                    scoring='f1')

# %%
rsDtc.best_params_
# Out:
# {'preprocessor__contDataPipeLine__scaler': MinMaxScaler(),
#  'preprocessor__catNominalDataPipeLine__oneHotEncoding__drop': 'first',
#  'dtcModel__max_depth': 6,
#  'dtcModel__criterion': 'entropy'}

# %%
yTestRsPred = rsDtc.predict(xTest)

# %%
yTrainRsPred = rsDtc.predict(xTrain)

# %%
accuracy_score(yTrain, yTrainRsPred)
# Out:
# 0.8611570247933884

# %%
accuracy_score(yTest, yTestRsPred)
# Out:
# 0.8251748251748252

# %%
rsHyper_df = pd.DataFrame(rsDtc.cv_results_)
rsHyper_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.017526      0.004724         0.004158        0.006895
# 1        0.010947      0.007018         0.006908        0.007532
# 2        0.012338      0.006236         0.005480        0.007242
# 3        0.014832      0.006981         0.007501        0.008113
# 4        0.013572      0.004542         0.005783        0.004877
# 5        0.011413      0.008428         0.006262        0.007669
# 6        0.017414      0.005240         0.007215        0.007691
# 7        0.018191      0.007636         0.006202        0.005442
# 8        0.015412      0.005493         0.006189        0.006058
# 9        0.014754      0.010339         0.007304        0.007161
# 10       0.013233      0.007200         0.005643        0.007282
# 11       0.012214      0.006237         0.003125        0.006249
# 12       0.010853      0.006700         0.003893        0.006190
# 13       0.015219      0.006593         0.008331        0.005852
# 14       0.017812      0.005419         0.006784        0.003579
# 15       0.018968      0.009002         0.003613        0.006217
# 16       0.012666      0.006931         0.005736        0.006897
# 17       0.016446      0.006807         0.006246        0.002748
# 18       0.017171      0.005161         0.006698        0.002037
# 19       0.017245      0.005688         0.006751        0.002094
#
#    param_preprocessor__contDataPipeLine__scaler  \
# 0                                MinMaxScaler()
# 1                              StandardScaler()
# 2                              StandardScaler()
# 3                                RobustScaler()
# 4                                MinMaxScaler()
# 5                                RobustScaler()
# 6                              StandardScaler()
# 7                                MinMaxScaler()
# 8                              StandardScaler()
# 9                                RobustScaler()
# 10                             StandardScaler()
# 11                               RobustScaler()
# 12                               RobustScaler()
# 13                               MinMaxScaler()
# 14                             StandardScaler()
# 15                             StandardScaler()
# 16                             StandardScaler()
# 17                               RobustScaler()
# 18                               MinMaxScaler()
# 19                             StandardScaler()
#
#    param_preprocessor__catNominalDataPipeLine__oneHotEncoding__drop  \
# 0                                               first
# 1                                               first
# 2                                                None
# 3                                                None
# 4                                               first
# 5                                                None
# 6                                               first
# 7                                               first
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                              first
# 12                                               None
# 13                                              first
# 14                                              first
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                              first
#
#    param_dtcModel__max_depth param_dtcModel__criterion  \
# 0                          3                   entropy
# 1                          2                  log_loss
# 2                         10                  log_loss
# 3                          6                      gini
# 4                          8                   entropy
# 5                          8                  log_loss
# 6                          3                      gini
# 7                          9                   entropy
# 8                          6                   entropy
# 9                          2                   entropy
# 10                         5                      gini
# 11                         3                      gini
# 12                         5                   entropy
# 13                         6                   entropy
# 14                         4                   entropy
# 15                         6                      gini
# 16                         5                   entropy
# 17                         3                   entropy
# 18                         9                      gini
# 19                         7                  log_loss
#
#                                                params  split0_test_score  ...  \
# 0   {'preprocessor__contDataPipeLine__scaler': Min...           0.666667  ...
# 1   {'preprocessor__contDataPipeLine__scaler': Sta...           0.689655  ...
# 2   {'preprocessor__contDataPipeLine__scaler': Sta...           0.787879  ...
# 3   {'preprocessor__contDataPipeLine__scaler': Rob...           0.787879  ...
# 4   {'preprocessor__contDataPipeLine__scaler': Min...           0.764706  ...
# 5   {'preprocessor__contDataPipeLine__scaler': Rob...           0.764706  ...
# 6   {'preprocessor__contDataPipeLine__scaler': Sta...           0.666667  ...
# 7   {'preprocessor__contDataPipeLine__scaler': Min...           0.787879  ...
# 8   {'preprocessor__contDataPipeLine__scaler': Sta...           0.812500  ...
# 9   {'preprocessor__contDataPipeLine__scaler': Rob...           0.689655  ...
# 10  {'preprocessor__contDataPipeLine__scaler': Sta...           0.764706  ...
# 11  {'preprocessor__contDataPipeLine__scaler': Rob...           0.666667  ...
# 12  {'preprocessor__contDataPipeLine__scaler': Rob...           0.733333  ...
# 13  {'preprocessor__contDataPipeLine__scaler': Min...           0.812500  ...
# 14  {'preprocessor__contDataPipeLine__scaler': Sta...           0.733333  ...
# 15  {'preprocessor__contDataPipeLine__scaler': Sta...           0.787879  ...
# 16  {'preprocessor__contDataPipeLine__scaler': Sta...           0.733333  ...
# 17  {'preprocessor__contDataPipeLine__scaler': Rob...           0.666667  ...
# 18  {'preprocessor__contDataPipeLine__scaler': Min...           0.774194  ...
# 19  {'preprocessor__contDataPipeLine__scaler': Sta...           0.812500  ...
#
#     split8_test_score  split9_test_score  split10_test_score  \
# 0            0.600000           0.740741            0.600000
# 1            0.645161           0.666667            0.562500
# 2            0.600000           0.571429            0.689655
# 3            0.645161           0.689655            0.647059
# 4            0.620690           0.600000            0.685714
# 5            0.620690           0.571429            0.705882
# 6            0.600000           0.666667            0.620690
# 7            0.709677           0.620690            0.705882
# 8            0.709677           0.689655            0.625000
# 9            0.645161           0.666667            0.562500
# 10           0.709677           0.689655            0.666667
# 11           0.600000           0.666667            0.620690
# 12           0.666667           0.666667            0.687500
# 13           0.709677           0.666667            0.666667
# 14           0.689655           0.727273            0.687500
# 15           0.666667           0.689655            0.647059
# 16           0.666667           0.666667            0.687500
# 17           0.600000           0.740741            0.600000
# 18           0.709677           0.645161            0.647059
# 19           0.666667           0.625000            0.685714
#
#     split11_test_score  split12_test_score  split13_test_score  \
# 0             0.774194            0.800000            0.857143
# 1             0.774194            0.666667            0.827586
# 2             0.866667            0.774194            0.769231
# 3             0.800000            0.814815            0.774194
# 4             0.800000            0.827586            0.740741
# 5             0.800000            0.785714            0.740741
# 6             0.827586            0.800000            0.857143
# 7             0.827586            0.800000            0.769231
# 8             0.800000            0.866667            0.774194
# 9             0.774194            0.666667            0.827586
# 10            0.800000            0.857143            0.774194
# 11            0.827586            0.800000            0.857143
# 12            0.833333            0.827586            0.774194
# 13            0.800000            0.896552            0.774194
# 14            0.827586            0.857143            0.774194
# 15            0.800000            0.785714            0.774194
# 16            0.833333            0.800000            0.774194
# 17            0.774194            0.800000            0.857143
# 18            0.800000            0.800000            0.666667
# 19            0.838710            0.785714            0.720000
#
#     split14_test_score  mean_test_score  std_test_score  rank_test_score
# 0             0.709677         0.722117        0.081832               11
# 1             0.545455         0.666628        0.069704               19
# 2             0.740741         0.705491        0.112752               18
# 3             0.774194         0.725877        0.069514                9
# 4             0.666667         0.707109        0.073240               16
# 5             0.666667         0.706122        0.076193               17
# 6             0.666667         0.720941        0.083841               13
# 7             0.800000         0.727341        0.101798                8
# 8             0.785714         0.753985        0.089450                3
# 9             0.545455         0.666628        0.069704               19
# 10            0.758621         0.754386        0.062456                2
# 11            0.666667         0.720941        0.083841               13
# 12            0.758621         0.747662        0.066363                5
# 13            0.785714         0.754819        0.090080                1
# 14            0.758621         0.753590        0.062761                4
# 15            0.774194         0.725371        0.065900               10
# 16            0.758621         0.745823        0.064478                6
# 17            0.709677         0.722117        0.081832               11
# 18            0.714286         0.719087        0.070637               15
# 19            0.838710         0.737849        0.087277                7
#
# [20 rows x 27 columns]

# %%
rsHyper_df.columns
# Out:
# Index(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time',
#        'param_preprocessor__contDataPipeLine__scaler',
#        'param_preprocessor__catNominalDataPipeLine__oneHotEncoding__drop',
#        'param_dtcModel__max_depth', 'param_dtcModel__criterion', 'params',
#        'split0_test_score', 'split1_test_score', 'split2_test_score',
#        'split3_test_score', 'split4_test_score', 'split5_test_score',
#        'split6_test_score', 'split7_test_score', 'split8_test_score',
#        'split9_test_score', 'split10_test_score', 'split11_test_score',
#        'split12_test_score', 'split13_test_score', 'split14_test_score',
#        'mean_test_score', 'std_test_score', 'rank_test_score'],
#       dtype='object')

# %%
rsHyper_df.sort_values(by='mean_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 9        0.014754      0.010339         0.007304        0.007161
# 1        0.010947      0.007018         0.006908        0.007532
# 2        0.012338      0.006236         0.005480        0.007242
# 5        0.011413      0.008428         0.006262        0.007669
# 4        0.013572      0.004542         0.005783        0.004877
# 18       0.017171      0.005161         0.006698        0.002037
# 6        0.017414      0.005240         0.007215        0.007691
# 11       0.012214      0.006237         0.003125        0.006249
# 17       0.016446      0.006807         0.006246        0.002748
# 0        0.017526      0.004724         0.004158        0.006895
# 15       0.018968      0.009002         0.003613        0.006217
# 3        0.014832      0.006981         0.007501        0.008113
# 7        0.018191      0.007636         0.006202        0.005442
# 19       0.017245      0.005688         0.006751        0.002094
# 16       0.012666      0.006931         0.005736        0.006897
# 12       0.010853      0.006700         0.003893        0.006190
# 14       0.017812      0.005419         0.006784        0.003579
# 8        0.015412      0.005493         0.006189        0.006058
# 10       0.013233      0.007200         0.005643        0.007282
# 13       0.015219      0.006593         0.008331        0.005852
#
#    param_preprocessor__contDataPipeLine__scaler  \
# 9                                RobustScaler()
# 1                              StandardScaler()
# 2                              StandardScaler()
# 5                                RobustScaler()
# 4                                MinMaxScaler()
# 18                               MinMaxScaler()
# 6                              StandardScaler()
# 11                               RobustScaler()
# 17                               RobustScaler()
# 0                                MinMaxScaler()
# 15                             StandardScaler()
# 3                                RobustScaler()
# 7                                MinMaxScaler()
# 19                             StandardScaler()
# 16                             StandardScaler()
# 12                               RobustScaler()
# 14                             StandardScaler()
# 8                              StandardScaler()
# 10                             StandardScaler()
# 13                               MinMaxScaler()
#
#    param_preprocessor__catNominalDataPipeLine__oneHotEncoding__drop  \
# 9                                                None
# 1                                               first
# 2                                                None
# 5                                                None
# 4                                               first
# 18                                               None
# 6                                               first
# 11                                              first
# 17                                               None
# 0                                               first
# 15                                               None
# 3                                                None
# 7                                               first
# 19                                              first
# 16                                               None
# 12                                               None
# 14                                              first
# 8                                                None
# 10                                               None
# 13                                              first
#
#    param_dtcModel__max_depth param_dtcModel__criterion  \
# 9                          2                   entropy
# 1                          2                  log_loss
# 2                         10                  log_loss
# 5                          8                  log_loss
# 4                          8                   entropy
# 18                         9                      gini
# 6                          3                      gini
# 11                         3                      gini
# 17                         3                   entropy
# 0                          3                   entropy
# 15                         6                      gini
# 3                          6                      gini
# 7                          9                   entropy
# 19                         7                  log_loss
# 16                         5                   entropy
# 12                         5                   entropy
# 14                         4                   entropy
# 8                          6                   entropy
# 10                         5                      gini
# 13                         6                   entropy
#
#                                                params  split0_test_score  ...  \
# 9   {'preprocessor__contDataPipeLine__scaler': Rob...           0.689655  ...
# 1   {'preprocessor__contDataPipeLine__scaler': Sta...           0.689655  ...
# 2   {'preprocessor__contDataPipeLine__scaler': Sta...           0.787879  ...
# 5   {'preprocessor__contDataPipeLine__scaler': Rob...           0.764706  ...
# 4   {'preprocessor__contDataPipeLine__scaler': Min...           0.764706  ...
# 18  {'preprocessor__contDataPipeLine__scaler': Min...           0.774194  ...
# 6   {'preprocessor__contDataPipeLine__scaler': Sta...           0.666667  ...
# 11  {'preprocessor__contDataPipeLine__scaler': Rob...           0.666667  ...
# 17  {'preprocessor__contDataPipeLine__scaler': Rob...           0.666667  ...
# 0   {'preprocessor__contDataPipeLine__scaler': Min...           0.666667  ...
# 15  {'preprocessor__contDataPipeLine__scaler': Sta...           0.787879  ...
# 3   {'preprocessor__contDataPipeLine__scaler': Rob...           0.787879  ...
# 7   {'preprocessor__contDataPipeLine__scaler': Min...           0.787879  ...
# 19  {'preprocessor__contDataPipeLine__scaler': Sta...           0.812500  ...
# 16  {'preprocessor__contDataPipeLine__scaler': Sta...           0.733333  ...
# 12  {'preprocessor__contDataPipeLine__scaler': Rob...           0.733333  ...
# 14  {'preprocessor__contDataPipeLine__scaler': Sta...           0.733333  ...
# 8   {'preprocessor__contDataPipeLine__scaler': Sta...           0.812500  ...
# 10  {'preprocessor__contDataPipeLine__scaler': Sta...           0.764706  ...
# 13  {'preprocessor__contDataPipeLine__scaler': Min...           0.812500  ...
#
#     split8_test_score  split9_test_score  split10_test_score  \
# 9            0.645161           0.666667            0.562500
# 1            0.645161           0.666667            0.562500
# 2            0.600000           0.571429            0.689655
# 5            0.620690           0.571429            0.705882
# 4            0.620690           0.600000            0.685714
# 18           0.709677           0.645161            0.647059
# 6            0.600000           0.666667            0.620690
# 11           0.600000           0.666667            0.620690
# 17           0.600000           0.740741            0.600000
# 0            0.600000           0.740741            0.600000
# 15           0.666667           0.689655            0.647059
# 3            0.645161           0.689655            0.647059
# 7            0.709677           0.620690            0.705882
# 19           0.666667           0.625000            0.685714
# 16           0.666667           0.666667            0.687500
# 12           0.666667           0.666667            0.687500
# 14           0.689655           0.727273            0.687500
# 8            0.709677           0.689655            0.625000
# 10           0.709677           0.689655            0.666667
# 13           0.709677           0.666667            0.666667
#
#     split11_test_score  split12_test_score  split13_test_score  \
# 9             0.774194            0.666667            0.827586
# 1             0.774194            0.666667            0.827586
# 2             0.866667            0.774194            0.769231
# 5             0.800000            0.785714            0.740741
# 4             0.800000            0.827586            0.740741
# 18            0.800000            0.800000            0.666667
# 6             0.827586            0.800000            0.857143
# 11            0.827586            0.800000            0.857143
# 17            0.774194            0.800000            0.857143
# 0             0.774194            0.800000            0.857143
# 15            0.800000            0.785714            0.774194
# 3             0.800000            0.814815            0.774194
# 7             0.827586            0.800000            0.769231
# 19            0.838710            0.785714            0.720000
# 16            0.833333            0.800000            0.774194
# 12            0.833333            0.827586            0.774194
# 14            0.827586            0.857143            0.774194
# 8             0.800000            0.866667            0.774194
# 10            0.800000            0.857143            0.774194
# 13            0.800000            0.896552            0.774194
#
#     split14_test_score  mean_test_score  std_test_score  rank_test_score
# 9             0.545455         0.666628        0.069704               19
# 1             0.545455         0.666628        0.069704               19
# 2             0.740741         0.705491        0.112752               18
# 5             0.666667         0.706122        0.076193               17
# 4             0.666667         0.707109        0.073240               16
# 18            0.714286         0.719087        0.070637               15
# 6             0.666667         0.720941        0.083841               13
# 11            0.666667         0.720941        0.083841               13
# 17            0.709677         0.722117        0.081832               11
# 0             0.709677         0.722117        0.081832               11
# 15            0.774194         0.725371        0.065900               10
# 3             0.774194         0.725877        0.069514                9
# 7             0.800000         0.727341        0.101798                8
# 19            0.838710         0.737849        0.087277                7
# 16            0.758621         0.745823        0.064478                6
# 12            0.758621         0.747662        0.066363                5
# 14            0.758621         0.753590        0.062761                4
# 8             0.785714         0.753985        0.089450                3
# 10            0.758621         0.754386        0.062456                2
# 13            0.785714         0.754819        0.090080                1
#
# [20 rows x 27 columns]

# %%
(rsHyper_df['mean_test_score'])
# Out:
# 0     0.722117
# 1     0.666628
# 2     0.705491
# 3     0.725877
# 4     0.707109
# 5     0.706122
# 6     0.720941
# 7     0.727341
# 8     0.753985
# 9     0.666628
# 10    0.754386
# 11    0.720941
# 12    0.747662
# 13    0.754819
# 14    0.753590
# 15    0.725371
# 16    0.745823
# 17    0.722117
# 18    0.719087
# 19    0.737849
# Name: mean_test_score, dtype: float64
